# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df_cars = pd.read_csv('vehicles.csv')
df_cars
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0             95           48                    83           178
# 1             91           41                    84           141
# 2            104           50                   106           209
# 3             93           41                    82           159
# 4             85           44                    70           205
# ..           ...          ...                   ...           ...
# 841           93           39                    87           183
# 842           89           46                    84           163
# 843          106           54                   101           222
# 844           86           36                    78           146
# 845           85           36                    66           123
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                      72                       10            162
# ...

# %%
df_cars.describe()
# Out:
#        COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# count   846.000000   846.000000            846.000000    846.000000
# mean     93.678487    44.861702             82.088652    168.940898
# std       8.234474     6.169866             15.771533     33.472183
# min      73.000000    33.000000             40.000000    104.000000
# 25%      87.000000    40.000000             70.000000    141.000000
# 50%      93.000000    44.000000             80.000000    167.000000
# 75%     100.000000    49.000000             98.000000    195.000000
# max     119.000000    59.000000            112.000000    333.000000
#
#        PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# count            846.000000               846.000000     846.000000
# mean              61.693853                 8.567376     168.839243
# std                7.888251                 4.601217      33.244978
# min               47.000000                 2.000000     112.000000
# ...

# %%
#selecting the first three observations
df_cars[0:3]
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0           95           48                    83           178
# 1           91           41                    84           141
# 2          104           50                   106           209
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                    72                       10            162
# 1                    57                        9            149
# 2                    66                       10            207
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 0             42                      20                        159
# 1             45                      19                        143
# 2             32                      23                        158
#
#    SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 0                    176                    379                        184
# ...

# %%
#selecting first three columns
df_cars.iloc[:, 0:3]
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY
# 0             95           48                    83
# 1             91           41                    84
# 2            104           50                   106
# 3             93           41                    82
# 4             85           44                    70
# ..           ...          ...                   ...
# 841           93           39                    87
# 842           89           46                    84
# 843          106           54                   101
# 844           86           36                    78
# 845           85           36                    66
#
# [846 rows x 3 columns]

# %%
#third observation, third column with iloc
df_cars.iloc[2,2]
# Out:
# 106

# %%
#third observation, third column with loc
df_cars.loc[2, "DISTANCE_CIRCULARITY"]
# Out:
# 106

# %%
#slicing ranges
df_cars.iloc[5:7, 0:3]
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY
# 5          107           57                   106
# 6           97           43                    73

# %%
df_cars.iloc[:, :2]
# Out:
#      COMPACTNESS  CIRCULARITY
# 0             95           48
# 1             91           41
# 2            104           50
# 3             93           41
# 4             85           44
# ..           ...          ...
# 841           93           39
# 842           89           46
# 843          106           54
# 844           86           36
# 845           85           36
#
# [846 rows x 2 columns]

# %% [markdown]
# # Numpy

# %%
x = [4,5,6,7]
x_np = np.array(x)

# %%
x_np.mean()
# Out:
# 5.5

# %%
#mean of a particular variable
df_cars.iloc[:, 1:2].mean()
# Out:
# CIRCULARITY    44.861702
# dtype: float64

# %%
#summary statistics of a particular variable
df_cars["CIRCULARITY"].describe()
# Out:
# count    846.000000
# mean      44.861702
# std        6.169866
# min       33.000000
# 25%       40.000000
# 50%       44.000000
# 75%       49.000000
# max       59.000000
# Name: CIRCULARITY, dtype: float64

# %%
#from yt tutorial video (Broadcasting and Vectorized operations)
a = np.arange(4)

# %%
a
# Out:
# array([0, 1, 2, 3])

# %%
a >= 2
# Out:
# array([False, False,  True,  True])

# %%
a[a >= 2]
# Out:
# array([2, 3])

# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Pandas Series

# %%
#Pandas series
g7 = pd.Series([3.05, 6.95, 5.0, 6.7])

# %% [markdown]
# This series is a single column of a dataframe

# %%
g7
# Out:
# 0    3.05
# 1    6.95
# 2    5.00
# 3    6.70
# dtype: float64

# %%
g7.name = "hehe"
g7
# Out:
# 0    3.05
# 1    6.95
# 2    5.00
# 3    6.70
# Name: hehe, dtype: float64

# %%
g7.dtype
# Out:
# dtype('float64')

# %%
#selecting third value of third row
g7.iloc[2]
# Out:
# 5.0

# %%
#custom index
g7.index = ["lol", "hehe", "kuku", "hihi"]

# %%
g7
# Out:
# lol     3.05
# hehe    6.95
# kuku    5.00
# hihi    6.70
# Name: hehe, dtype: float64

# %%
#indexing via the custom indices
g7["hehe"]
# Out:
# 6.95

# %%
#selecting multiple values via indexing
g7[["lol", "hehe"]]   #upper limit is included
# Out:
# lol     3.05
# hehe    6.95
# Name: hehe, dtype: float64

# %%
#selecting multiple values via iloc
g7.iloc[[0,1]]
# Out:
# lol     3.05
# hehe    6.95
# Name: hehe, dtype: float64

# %%
g7.mean()
# Out:
# 5.425

# %%
g7 > 5
# Out:
# lol     False
# hehe     True
# kuku    False
# hihi     True
# Name: hehe, dtype: bool

# %%
g7[g7 >5]
# Out:
# hehe    6.95
# hihi    6.70
# Name: hehe, dtype: float64

# %%
g7[g7 > g7.mean()]
# Out:
# hehe    6.95
# hihi    6.70
# Name: hehe, dtype: float64

# %% [markdown]
# ### Pandas Dataframes

# %%
#Dataframe from earlier example
df_cars
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0             95           48                    83           178
# 1             91           41                    84           141
# 2            104           50                   106           209
# 3             93           41                    82           159
# 4             85           44                    70           205
# ..           ...          ...                   ...           ...
# 841           93           39                    87           183
# 842           89           46                    84           163
# 843          106           54                   101           222
# 844           86           36                    78           146
# 845           85           36                    66           123
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                      72                       10            162
# ...

# %% [markdown]
# A Pandas Dataframe consists of  multiple columns. Each column is a Pandas Series.

# %%
df_cars.iloc[:,2:4]
# Out:
#      DISTANCE_CIRCULARITY  RADIUS_RATIO
# 0                      83           178
# 1                      84           141
# 2                     106           209
# 3                      82           159
# 4                      70           205
# ..                    ...           ...
# 841                    87           183
# 842                    84           163
# 843                   101           222
# 844                    78           146
# 845                    66           123
#
# [846 rows x 2 columns]

# %%
df_cars.iloc[:,2:4].mean()
# Out:
# DISTANCE_CIRCULARITY     82.088652
# RADIUS_RATIO            168.940898
# dtype: float64

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   COMPACTNESS                846 non-null    int64
#  1   CIRCULARITY                846 non-null    int64
#  2   DISTANCE_CIRCULARITY       846 non-null    int64
#  3   RADIUS_RATIO               846 non-null    int64
#  4   PR.AXIS_ASPECT_RATIO       846 non-null    int64
#  5   MAX.LENGTH_ASPECT_RATIO    846 non-null    int64
#  6   SCATTER_RATIO              846 non-null    int64
#  7   ELONGATEDNESS              846 non-null    int64
#  8   PR.AXIS_RECTANGULARITY     846 non-null    int64
#  9   MAX.LENGTH_RECTANGULARITY  846 non-null    int64
#  10  SCALED_VARIANCE_MAJOR      846 non-null    int64
#  11  SCALED_VARIANCE_MINOR      846 non-null    int64
#  12  SCALED_RADIUS_OF_GYRATION  846 non-null    int64
# ...

# %%
df_cars.describe()
# Out:
#        COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# count   846.000000   846.000000            846.000000    846.000000
# mean     93.678487    44.861702             82.088652    168.940898
# std       8.234474     6.169866             15.771533     33.472183
# min      73.000000    33.000000             40.000000    104.000000
# 25%      87.000000    40.000000             70.000000    141.000000
# 50%      93.000000    44.000000             80.000000    167.000000
# 75%     100.000000    49.000000             98.000000    195.000000
# max     119.000000    59.000000            112.000000    333.000000
#
#        PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# count            846.000000               846.000000     846.000000
# mean              61.693853                 8.567376     168.839243
# std                7.888251                 4.601217      33.244978
# min               47.000000                 2.000000     112.000000
# ...

# %%
#Selecting rows by index by using the loc attribute
df_cars.iloc[3:5]
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 3           93           41                    82           159
# 4           85           44                    70           205
#
#    PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 3                    63                        9            144
# 4                   103                       52            149
#
#    ELONGATEDNESS  PR.AXIS_RECTANGULARITY  MAX.LENGTH_RECTANGULARITY  \
# 3             46                      19                        143
# 4             45                      19                        144
#
#    SCALED_VARIANCE_MAJOR  SCALED_VARIANCE_MINOR  SCALED_RADIUS_OF_GYRATION  \
# 3                    160                    309                        127
# 4                    241                    325                        188
#
#    SKEWNESS_ABOUT_MAJOR  SKEWNESS_ABOUT_MINOR  KURTOSIS_ABOUT_MAJOR  \
# 3                    63                     6                    10
# ...

# %%
#selecting entire column
df_cars["COMPACTNESS"]
# Out:
# 0       95
# 1       91
# 2      104
# 3       93
# 4       85
#       ...
# 841     93
# 842     89
# 843    106
# 844     86
# 845     85
# Name: COMPACTNESS, Length: 846, dtype: int64

# %%
#using iloc to select rows and columns
df_cars.iloc[1:5, 0:3]
# Out:
#    COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY
# 1           91           41                    84
# 2          104           50                   106
# 3           93           41                    82
# 4           85           44                    70

# %%
#conditional selection
df_cars.loc[df_cars["CIRCULARITY"] > 45]
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0             95           48                    83           178
# 2            104           50                   106           209
# 5            107           57                   106           172
# 12            88           46                    74           171
# 14            94           49                    79           203
# ..           ...          ...                   ...           ...
# 833           92           46                    83           154
# 835          111           58                   105           183
# 837           94           46                    77           169
# 842           89           46                    84           163
# 843          106           54                   101           222
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                      72                       10            162
# ...

# %%
#more complex conditional selection
df_cars.loc[df_cars["COMPACTNESS"] > 50, ["COMPACTNESS", "CIRCULARITY"],]
# Out:
#      COMPACTNESS  CIRCULARITY
# 0             95           48
# 1             91           41
# 2            104           50
# 3             93           41
# 4             85           44
# ..           ...          ...
# 841           93           39
# 842           89           46
# 843          106           54
# 844           86           36
# 845           85           36
#
# [846 rows x 2 columns]

# %%
circularity = df_cars["CIRCULARITY"]

# %%
circularity.mean()
# Out:
# 44.861702127659576

# %%
circularity.sum()
# Out:
# 37953

# %%
#Access a single value for a row/column label pair
df_cars.at[1,"COMPACTNESS"]
# Out:
# 91

# %%
#plotting two variables into one plot
df_cars.loc[:, ["CIRCULARITY" , "COMPACTNESS"]].plot()

# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd

# %%
df_cars["COMPACTNESS"].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 841    False
# 842    False
# 843    False
# 844    False
# 845    False
# Name: COMPACTNESS, Length: 846, dtype: bool

# %%
df_cars.dropna()
# Out:
#      COMPACTNESS  CIRCULARITY  DISTANCE_CIRCULARITY  RADIUS_RATIO  \
# 0             95           48                    83           178
# 1             91           41                    84           141
# 2            104           50                   106           209
# 3             93           41                    82           159
# 4             85           44                    70           205
# ..           ...          ...                   ...           ...
# 841           93           39                    87           183
# 842           89           46                    84           163
# 843          106           54                   101           222
# 844           86           36                    78           146
# 845           85           36                    66           123
#
#      PR.AXIS_ASPECT_RATIO  MAX.LENGTH_ASPECT_RATIO  SCATTER_RATIO  \
# 0                      72                       10            162
# ...

# %%
df_cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 846 entries, 0 to 845
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   COMPACTNESS                846 non-null    int64
#  1   CIRCULARITY                846 non-null    int64
#  2   DISTANCE_CIRCULARITY       846 non-null    int64
#  3   RADIUS_RATIO               846 non-null    int64
#  4   PR.AXIS_ASPECT_RATIO       846 non-null    int64
#  5   MAX.LENGTH_ASPECT_RATIO    846 non-null    int64
#  6   SCATTER_RATIO              846 non-null    int64
#  7   ELONGATEDNESS              846 non-null    int64
#  8   PR.AXIS_RECTANGULARITY     846 non-null    int64
#  9   MAX.LENGTH_RECTANGULARITY  846 non-null    int64
#  10  SCALED_VARIANCE_MAJOR      846 non-null    int64
#  11  SCALED_VARIANCE_MINOR      846 non-null    int64
#  12  SCALED_RADIUS_OF_GYRATION  846 non-null    int64
# ...

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_cars.iloc[:,2:3]
# Out:
#      DISTANCE_CIRCULARITY
# 0                      83
# 1                      84
# 2                     106
# 3                      82
# 4                      70
# ..                    ...
# 841                    87
# 842                    84
# 843                   101
# 844                    78
# 845                    66
#
# [846 rows x 1 columns]

# %%
df_cars.iloc[:,2:3].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000026C814AA488>]],
#       dtype=object)
